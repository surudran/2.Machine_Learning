# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#data variablecsv value is stored
data = pd.read_csv('Salary_Data.csv')

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
independent  = data[["YearsExperience"]] #Independent Variable, years of Experience, datatype float
dependent = data[["Salary"]] # Dependent Variable, Salary, datatype float

# %%
plt.scatter(independent,dependent)
plt.xlabel('YearsExperience',fontsize=20)
plt.ylabel('Salary',fontsize=20)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent,dependent, test_size = 1/3, random_state = 0)

# %%
y_test
# Out:
#       Salary
# 2    37731.0
# 28  122391.0
# 13   57081.0
# 10   63218.0
# 26  116969.0
# 24  109431.0
# 27  112635.0
# 11   55794.0
# 17   83088.0
# 22  101302.0

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train) #y=W*x1+b0 for this equation we got value for W and b0
# Out:
# LinearRegression()

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
# Viewing the W and bo value
weight=regressor.coef_
print("Weight of the model={}".format(weight))
bais=regressor.intercept_
print("Intercept of the model={}".format(bais))
# Out:
# Weight of the model=[[9345.94244312]]
# Intercept of the model=[26816.19224403]

# %%
y_pred=regressor.predict(X_test)

# %%
y_pred
# Out:
# array([[ 40835.10590871],
#        [123079.39940819],
#        [ 65134.55626083],
#        [ 63265.36777221],
#        [115602.64545369],
#        [108125.8914992 ],
#        [116537.23969801],
#        [ 64199.96201652],
#        [ 76349.68719258],
#        [100649.1375447 ]])

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.9749154407708353

# %%
import pickle
filename = 'finalized_model.sav'
pickle.dump(regressor, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('finalized_model.sav', 'rb'))
result = loaded_model.predict([[15]])
print(result)
# Out:
# [[167005.32889087]]
# /Users/sutharsanurudrasingam/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
prediction_input=int(input("Enter the Prediction input value:"))
# Out:
# Enter the Prediction input value: 15

# %%
Future_Prediction=regressor.predict([[prediction_input]]) # change the parameter, play with it.
print("Future_Predic
