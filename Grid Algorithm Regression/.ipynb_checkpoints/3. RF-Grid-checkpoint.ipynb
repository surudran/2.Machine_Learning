# %%
#importing the Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#read_csv function called to read the csv file and store to dataset
dataset = pd.read_csv("insurance_pre.csv")

# %%
#display values from dataset
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#convert categarical data to numerical data using the function get_dummies, drop_first will delete the first column
dataset = pd.get_dummies(dataset, drop_first=True)

# %%
#display the values from dataset
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
#display columns from dataset
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#splitting input values into independent as input
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
#display input values from varialbe independent
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
#splitting output values into variable dependent
dependent = dataset['charges']

# %%
#display the output values from dependent
dependent
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
#splitting the data into training and test sets using sklearn model selection
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size = 1/3, random_state =0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Procedure to import specific function RandomForestRegressor from sklearn.ensemble
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'max_features':['sqrt', 'log2'],
           'n_estimators':[10,50,80,100]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

#fitting the model for grid search
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 50, 80, 100]},
#              verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test) 
   
# print classification report 
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)

print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 80}: 0.873981329437285

# %%
table = pd.DataFrame.from_dict(re)

# %%
#display table
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.031511      0.006989         0.003461        0.000936
# 1        0.190528      0.005537         0.010435        0.003853
# 2        0.266599      0.023128         0.009050        0.000113
# 3        0.298914      0.005261         0.012344        0.001361
# 4        0.030031      0.001136         0.002307        0.000137
# 5        0.148170      0.003120         0.006533        0.000121
# 6        0.247270      0.008284         0.011034        0.001288
# 7        0.336509      0.027852         0.014928        0.003388
# 8        0.031231      0.003463         0.002331        0.000236
# 9        0.173941      0.020366         0.009158        0.003596
# 10       0.306938      0.011180         0.012212        0.001770
# 11       0.371624      0.008312         0.015773        0.002055
# 12       0.039082      0.006071         0.003828        0.002273
# 13       0.179226      0.013970         0.008194        0.003125
# 14       0.286342      0.011820         0.012856        0.002309
# 15       0.366565      0.004612         0.015232        0.003774
# 16       0.105607      0.005499         0.002446        0.000284
# 17       0.604224      0.133767         0.008043        0.002599
# 18       0.987356      0.118204         0.009832        0.001289
# 19       1.079414      0.217724         0.010980        0.000175
# 20       0.163350      0.072249         0.004000        0.003196
# 21       0.498561      0.056634         0.006325        0.000364
# 22       0.686552      0.008593         0.010337        0.002255
# 23       0.870273      0.019375         0.011067        0.000431
# 24       0.042446      0.003995         0.002347        0.000470
# 25       0.204186      0.005224         0.006243        0.000381
# 26       0.338753      0.016091         0.008957        0.000220
# 27       0.403589      0.009169         0.012701        0.001416
# 28       0.041864      0.001980         0.002191        0.000099
# 29       0.205595      0.006583         0.006668        0.000643
# 30       0.327893      0.009858         0.009651        0.001126
# 31       0.339650      0.028668         0.010827        0.003273
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                  10
# 1    squared_error               sqrt                  50
# 2    squared_error               sqrt                  80
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  10
# 5    squared_error               log2                  50
# 6    squared_error               log2                  80
# 7    squared_error               log2                 100
# 8     friedman_mse               sqrt                  10
# 9     friedman_mse               sqrt                  50
# 10    friedman_mse               sqrt                  80
# 11    friedman_mse               sqrt                 100
# 12    friedman_mse               log2                  10
# 13    friedman_mse               log2                  50
# 14    friedman_mse               log2                  80
# 15    friedman_mse               log2                 100
# 16  absolute_error               sqrt                  10
# 17  absolute_error               sqrt                  50
# 18  absolute_error               sqrt                  80
# 19  absolute_error               sqrt                 100
# 20  absolute_error               log2                  10
# 21  absolute_error               log2                  50
# 22  absolute_error               log2                  80
# 23  absolute_error               log2                 100
# 24         poisson               sqrt                  10
# 25         poisson               sqrt                  50
# 26         poisson               sqrt                  80
# 27         poisson               sqrt                 100
# 28         poisson               log2                  10
# 29         poisson               log2                  50
# 30         poisson               log2                  80
# 31         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.794413
# 1   {'criterion': 'squared_error', 'max_features':...           0.804265
# 2   {'criterion': 'squared_error', 'max_features':...           0.798775
# 3   {'criterion': 'squared_error', 'max_features':...           0.799335
# 4   {'criterion': 'squared_error', 'max_features':...           0.795866
# 5   {'criterion': 'squared_error', 'max_features':...           0.790852
# 6   {'criterion': 'squared_error', 'max_features':...           0.808790
# 7   {'criterion': 'squared_error', 'max_features':...           0.808718
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.776405
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.793629
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.807698
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.801189
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.798407
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.812350
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.797738
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.809097
# 16  {'criterion': 'absolute_error', 'max_features'...           0.779555
# 17  {'criterion': 'absolute_error', 'max_features'...           0.792878
# 18  {'criterion': 'absolute_error', 'max_features'...           0.806992
# 19  {'criterion': 'absolute_error', 'max_features'...           0.804796
# 20  {'criterion': 'absolute_error', 'max_features'...           0.780281
# 21  {'criterion': 'absolute_error', 'max_features'...           0.794767
# 22  {'criterion': 'absolute_error', 'max_features'...           0.799885
# 23  {'criterion': 'absolute_error', 'max_features'...           0.800345
# 24  {'criterion': 'poisson', 'max_features': 'sqrt...           0.785944
# 25  {'criterion': 'poisson', 'max_features': 'sqrt...           0.808675
# 26  {'criterion': 'poisson', 'max_features': 'sqrt...           0.802883
# 27  {'criterion': 'poisson', 'max_features': 'sqrt...           0.806918
# 28  {'criterion': 'poisson', 'max_features': 'log2...           0.795051
# 29  {'criterion': 'poisson', 'max_features': 'log2...           0.801359
# 30  {'criterion': 'poisson', 'max_features': 'log2...           0.808086
# 31  {'criterion': 'poisson', 'max_features': 'log2...           0.797225
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.734120           0.833961           0.802574
# 1            0.757952           0.831883           0.831776
# 2            0.767356           0.833317           0.829699
# 3            0.776370           0.836469           0.836271
# 4            0.756298           0.840552           0.772567
# 5            0.771494           0.831736           0.827767
# 6            0.771132           0.839309           0.828220
# 7            0.765463           0.839545           0.832529
# 8            0.720170           0.833884           0.810534
# 9            0.776583           0.831305           0.834388
# 10           0.764135           0.838225           0.838724
# 11           0.767683           0.834731           0.836410
# 12           0.741555           0.799829           0.791166
# 13           0.767267           0.836587           0.825816
# 14           0.776263           0.838660           0.828913
# 15           0.760334           0.839448           0.837893
# 16           0.740579           0.839887           0.792911
# 17           0.781031           0.841433           0.823599
# 18           0.779750           0.831053           0.823803
# 19           0.772007           0.838729           0.819600
# 20           0.726183           0.819179           0.801109
# 21           0.759945           0.841120           0.812687
# 22           0.768448           0.834005           0.829846
# 23           0.767287           0.839713           0.824761
# 24           0.738737           0.830301           0.771662
# 25           0.769775           0.841196           0.832982
# 26           0.772218           0.837170           0.829811
# 27           0.768630           0.838614           0.836473
# 28           0.747844           0.838014           0.803837
# 29           0.763973           0.828589           0.830040
# 30           0.756712           0.838705           0.829701
# 31           0.759706           0.844303           0.833664
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.752989         0.783611        0.035773               26
# 1            0.752390         0.795653        0.034597               23
# 2            0.762716         0.798373        0.029786               21
# 3            0.757874         0.801264        0.031531                8
# 4            0.748989         0.782854        0.033034               27
# 5            0.770028         0.798375        0.026682               20
# 6            0.765849         0.802660        0.029608                2
# 7            0.764142         0.802079        0.032109                4
# 8            0.713674         0.770933        0.047784               32
# 9            0.760649         0.799311        0.029318               18
# 10           0.755239         0.800804        0.035515               10
# 11           0.765752         0.801153        0.030803                9
# 12           0.753537         0.776899        0.024441               29
# 13           0.758668         0.800138        0.031424               12
# 14           0.756947         0.799704        0.030829               14
# 15           0.762047         0.801764        0.034851                5
# 16           0.735647         0.777716        0.038075               28
# 17           0.762096         0.800207        0.028708               11
# 18           0.772183         0.802756        0.023348                1
# 19           0.761905         0.799408        0.028776               16
# 20           0.747799         0.774910        0.034013               31
# 21           0.756336         0.792971        0.032072               24
# 22           0.764863         0.799409        0.029242               15
# 23           0.764729         0.799367        0.030008               17
# 24           0.748623         0.775053        0.032249               30
# 25           0.754112         0.801348        0.034265                7
# 26           0.766510         0.801719        0.028835                6
# 27           0.761192         0.802365        0.032654                3
# 28           0.753370         0.787623        0.033505               25
# 29           0.759718         0.796736        0.030295               22
# 30           0.762099         0.799061        0.033916               19
# 31           0.764842         0.799948        0.034535               13

# %%
age_input = float(input("Age:"))
bmi_input = float(input("BMI:"))
children_input = float(input("Children:"))
sex_male_input = int(input("Sex Male 0 or 1:"))
smoker_yes_input = int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 43
# BMI: 35
# Children: 0
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction = grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]]) # change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[16598.70930688]
