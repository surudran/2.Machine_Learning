# %%
#importing the Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#read_csv function called to read the csv file and store to dataset
dataset = pd.read_csv("insurance_pre.csv")

# %%
#display values from dataset
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#convert categarical data to numerical data using the function get_dummies, drop_first will delete the first column
dataset = pd.get_dummies(dataset, drop_first = True)

# %%
#display the values from dataset
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
#display columns from dataset
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#splitting input values into independent as input
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
#display input values from varialbe independent
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
#splitting output values into variable dependent
dependent = dataset[['charges']]

# %%
#display the output values from dependent
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#procedure to import GridSearchV and DecisionTreeRegressor Functions and save the model
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'], 'max_features': ['sqrt', 'log2'], 'splitter':['best','random']}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3, n_jobs = -1)

# fitting the model for grid search
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# print the best parameter after tuning
#print (grid.best_params_)
re=grid.cv_results_
print ("The R_score value for the best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for the best parameter {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'}:

# %%
table = pd.DataFrame.from_dict(re)

# %%
#display table
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.008465      0.000233         0.004173        0.000182
# 1        0.009602      0.002761         0.005465        0.002446
# 2        0.011921      0.002624         0.006959        0.003236
# 3        0.009079      0.001900         0.007739        0.003909
# 4        0.008591      0.001037         0.004134        0.000300
# 5        0.006674      0.001036         0.006765        0.003077
# 6        0.007109      0.000810         0.008094        0.003493
# 7        0.006717      0.001197         0.004431        0.001165
# 8        0.029585      0.003515         0.004068        0.000620
# 9        0.021673      0.002353         0.003794        0.000403
# 10       0.028379      0.001199         0.004159        0.001055
# 11       0.018290      0.003806         0.004245        0.000960
# 12       0.010371      0.000994         0.004064        0.000955
# 13       0.008694      0.000828         0.004083        0.000405
# 14       0.008867      0.000181         0.003351        0.000932
# 15       0.006672      0.001376         0.002800        0.000424
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.716407
# 1   {'criterion': 'squared_error', 'max_features':...           0.705458
# 2   {'criterion': 'squared_error', 'max_features':...           0.759587
# 3   {'criterion': 'squared_error', 'max_features':...           0.697836
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.766271
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.655873
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.713264
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.722422
# 8   {'criterion': 'absolute_error', 'max_features'...           0.724415
# 9   {'criterion': 'absolute_error', 'max_features'...           0.697354
# 10  {'criterion': 'absolute_error', 'max_features'...           0.709239
# 11  {'criterion': 'absolute_error', 'max_features'...           0.729067
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.747667
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.685576
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.732020
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.640993
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.633636           0.760916           0.715074
# 1            0.599739           0.631739           0.654614
# 2            0.561668           0.727908           0.701641
# 3            0.529337           0.731724           0.667525
# 4            0.659141           0.632037           0.715790
# 5            0.627947           0.677744           0.693963
# 6            0.665074           0.584165           0.637635
# 7            0.511386           0.670858           0.558309
# 8            0.635261           0.645097           0.728009
# 9            0.650689           0.745420           0.665043
# 10           0.587547           0.537264           0.647240
# 11           0.658749           0.739955           0.685144
# 12           0.663217           0.668192           0.759596
# 13           0.555816           0.602512           0.709472
# 14           0.567021           0.765272           0.644955
# 15           0.589773           0.692253           0.696895
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.668860         0.698978        0.043763                5
# 1            0.690365         0.656383        0.038424               10
# 2            0.726417         0.695444        0.069372                6
# 3            0.604345         0.646154        0.071895               13
# 4            0.724877         0.699623        0.048058                3
# 5            0.571270         0.645359        0.043160               14
# 6            0.674264         0.654880        0.042863               11
# 7            0.763225         0.645240        0.095925               15
# 8            0.719803         0.690517        0.041300                7
# 9            0.761885         0.704078        0.043521                2
# 10           0.749486         0.646155        0.077396               12
# 11           0.682284         0.699040        0.030571                4
# 12           0.750044         0.717743        0.042706                1
# 13           0.616237         0.633923        0.056171               16
# 14           0.674748         0.676803        0.069204                8
# 15           0.675642         0.659111        0.039838                9

# %%
age_input = float(input("Age:"))
bmi_input = float(input("BMI:"))
children_input = float(input("Children:"))
sex_male_input = int(input("Sex Male 0 or 1:"))
smoker_yes_input = int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 34
# BMI: 45
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction = grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]]) # change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[39241.442]
# /Users/sutharsanurudrasingam/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
